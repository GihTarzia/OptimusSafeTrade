# %%
# %pip install pandas
# %pip install matplotlib
# %pip install yfinance
# %pip install openpyxl
# %pip install mplcyberpunk
# %pip install TA-Lib
# %pip install --upgrade setuptools

# %%
# %pip install pandas iqoptionapi ta
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install xgboost scikit-learn
# Out:
# ...
#    ---------------------------------------- 0.0/124.9 MB ? eta -:--:--
#    ---------------------------------------- 1.0/124.9 MB 5.4 MB/s eta 0:00:23
#     --------------------------------------- 2.1/124.9 MB 5.5 MB/s eta 0:00:23
#    - -------------------------------------- 3.4/124.9 MB 5.3 MB/s eta 0:00:23
#    - -------------------------------------- 4.5/124.9 MB 5.3 MB/s eta 0:00:23
#    - -------------------------------------- 5.5/124.9 MB 5.3 MB/s eta 0:00:23
#    -- ------------------------------------- 6.8/124.9 MB 5.3 MB/s eta 0:00:23
#    -- ------------------------------------- 7.6/124.9 MB 5.2 MB/s eta 0:00:23
#    -- ------------------------------------- 8.9/124.9 MB 5.2 MB/s eta 0:00:23
#    --- ------------------------------------ 10.0/124.9 MB 5.3 MB/s eta 0:00:22
#    --- ------------------------------------ 11.3/124.9 MB 5.3 MB/s eta 0:00:22
#    --- ------------------------------------ 12.3/124.9 MB 5.3 MB/s eta 0:00:22
# ...

# %%
# %pip install schedule
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install telegram
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Created wheel for telegram: filename=telegram-0.0.1-py3-none-any.whl size=1301 sha256=00b1c2b818b62a566faba3eb63ffe6b088d866e937ec1987869e9108bdacd054
#   Stored in directory: c:\users\gitar\appdata\local\pip\cache\wheels\ed\a7\da\985c884676d0871f049aaa23d93ca2eab485bad0475e0a4319
# Successfully built telegram
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip uninstall telegram
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install pandas==1.5.3
# %pip install numpy==1.23.5
# %pip install yfinance==0.2.18
# %pip install scikit-learn==1.2.2
# %pip install xgboost==1.7.5
# %pip install sqlalchemy==1.4.46
# %pip install colorama==0.4.6
# %pip install python-telegram-bot==20.3
# %pip install pyyaml==6.0.1
# %pip install schedule==1.2.0
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# ...
#      ---------------------------------------- 0.0/10.7 MB ? eta -:--:--
#      -- ------------------------------------- 0.8/10.7 MB 4.3 MB/s eta 0:00:03
#      ------ --------------------------------- 1.8/10.7 MB 4.4 MB/s eta 0:00:03
#      ---------- ----------------------------- 2.9/10.7 MB 4.5 MB/s eta 0:00:02
#      ------------- -------------------------- 3.7/10.7 MB 4.6 MB/s eta 0:00:02
#      ------------------ --------------------- 5.0/10.7 MB 4.8 MB/s eta 0:00:02
#      ---------------------- ----------------- 6.0/10.7 MB 5.0 MB/s eta 0:00:01
#      --------------------------- ------------ 7.3/10.7 MB 5.1 MB/s eta 0:00:01
#      ------------------------------- -------- 8.4/10.7 MB 5.1 MB/s eta 0:00:01
#      ------------------------------------ --- 9.7/10.7 MB 5.2 MB/s eta 0:00:01
# ...

# %%
# %pip install -r requirements.txt
# Out:
# ...
#   error: subprocess-exited-with-error
#
#   × Preparing metadata (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [11174 lines of output]
#       Partial import of sklearn during the build process.
#       test_program.c
#       Gerando c¢digo
#       Finalizada a gera‡Æo de c¢digo
#       test_program.c
#       LINK : warning LNK4044: op‡Æo nÆo reconhecida '/openmp'; ignorada
#       Gerando c¢digo
#       Finalizada a gera‡Æo de c¢digo
#       Compiling sklearn\__check_build\_check_build.pyx because it changed.
#       Compiling sklearn\_isotonic.pyx because it changed.
#       Compiling sklearn\_loss\_loss.pyx because it changed.
#       Compiling sklearn\cluster\_dbscan_inner.pyx because it changed.
#       Compiling sklearn\cluster\_hierarchical_fast.pyx because it changed.
#       Compiling sklearn\cluster\_k_means_common.pyx because it changed.
#       Compiling sklearn\cluster\_k_means_lloyd.pyx because it changed.
# ...

# %%
# %pip install optuna
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script mako-render.exe is installed in 'c:\Users\gitar\AppData\Local\Programs\Python\Python313\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script alembic.exe is installed in 'c:\Users\gitar\AppData\Local\Programs\Python\Python313\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script optuna.exe is installed in 'c:\Users\gitar\AppData\Local\Programs\Python\Python313\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
# %pip install plotly
# Out:
# ...
#    ---------------------------------------- 0.0/19.1 MB ? eta -:--:--
#    -- ------------------------------------- 1.0/19.1 MB 5.2 MB/s eta 0:00:04
#    ---- ----------------------------------- 2.1/19.1 MB 5.3 MB/s eta 0:00:04
#    ------ --------------------------------- 3.1/19.1 MB 5.2 MB/s eta 0:00:04
#    -------- ------------------------------- 4.2/19.1 MB 5.0 MB/s eta 0:00:03
#    ----------- ---------------------------- 5.2/19.1 MB 5.0 MB/s eta 0:00:03
#    ------------- -------------------------- 6.3/19.1 MB 5.1 MB/s eta 0:00:03
#    --------------- ------------------------ 7.6/19.1 MB 5.2 MB/s eta 0:00:03
#    ------------------ --------------------- 8.7/19.1 MB 5.2 MB/s eta 0:00:03
#    -------------------- ------------------- 10.0/19.1 MB 5.2 MB/s eta 0:00:02
#    ----------------------- ---------------- 11.0/19.1 MB 5.3 MB/s eta 0:00:02
#    ------------------------- -------------- 12.1/19.1 MB 5.3 MB/s eta 0:00:02
# ...

# %%
# %pip install talib-binary
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement talib-binary (from versions: none)
# ERROR: No matching distribution found for talib-binary

# %%
# %pip install pandas numpy yfinance colorama textblob
# Out:
# ...
#    ---------------------------------------- 0.0/626.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/626.3 kB ? eta -:--:--
#    --------------------------------- ------ 524.3/626.3 kB 3.7 MB/s eta 0:00:01
#    ---------------------------------------- 626.3/626.3 kB 3.8 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    --------------------------- ------------ 1.0/1.5 MB 5.1 MB/s eta 0:00:01
#    ---------------------------------------- 1.5/1.5 MB 4.2 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script tqdm.exe is installed in 'c:\Users\gitar\AppData\Local\Programs\Python\Python313\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script nltk.exe is installed in 'c:\Users\gitar\AppData\Local\Programs\Python\Python313\Scripts' which is not on PATH.
# ...

# %% [markdown]
# %pip install --upgrade setuptools

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
import yfinance as yf
import matplotlib as mpl
import mplcyberpunk

# %%
lista_tickers = ["EURUSD=X", "GBPUSD=X", "JPY=X", "EURJPY=X"]

# %%
dados_bancarios = yf.download(lista_tickers, start = "2010-01-01", end = "2022-04-30")

dados_bancarios = dados_bancarios["Adj Close"]

dados_bancarios
# Out:
# [*********************100%***********************]  4 of 4 completed
# Ticker                       EURJPY=X  EURUSD=X  GBPUSD=X       JPY=X
# Date
# 2010-01-01 00:00:00+00:00  133.710007  1.438994  1.613294   92.919998
# 2010-01-04 00:00:00+00:00  133.389999  1.442398  1.611370   92.495003
# 2010-01-05 00:00:00+00:00  131.529999  1.436596  1.599079   91.584999
# 2010-01-06 00:00:00+00:00  133.013000  1.440403  1.602384   92.356003
# 2010-01-07 00:00:00+00:00  133.748001  1.431803  1.593397   93.389999
# ...                               ...       ...       ...         ...
# 2022-04-25 00:00:00+00:00  139.028000  1.081105  1.283088  128.604996
# 2022-04-26 00:00:00+00:00  136.867004  1.071421  1.273999  127.744003
# 2022-04-27 00:00:00+00:00  135.449997  1.064362  1.258400  127.265999
# 2022-04-28 00:00:00+00:00  135.528000  1.055509  1.254186  128.393997
# 2022-04-29 00:00:00+00:00  137.391006  1.050420  1.246385  130.811005
#
# [3214 rows x 4 columns]

# %%
lucro_bancos = pd.read_excel("lucro_bancos_2010_2022.xlsx")

lucro_bancos
# Out:
#         data   EUR/USD   GBP/USD   USD/JPY   EUR/JPY
# 0 2009-12-31   8012282  10147522  10066608   1805899
# 1 2021-12-31  21945688  19710402  24988000  14987716

# %% [markdown]
# ### Conceitos importantes

# %%
data_frame_com_colunas_selecionadas = dados_bancarios[["EURUSD=X", "GBPUSD=X"]]
data_frame_com_colunas_selecionadas
# Out:
# Ticker                     EURUSD=X  GBPUSD=X
# Date
# 2010-01-01 00:00:00+00:00  1.438994  1.613294
# 2010-01-04 00:00:00+00:00  1.442398  1.611370
# 2010-01-05 00:00:00+00:00  1.436596  1.599079
# 2010-01-06 00:00:00+00:00  1.440403  1.602384
# 2010-01-07 00:00:00+00:00  1.431803  1.593397
# ...                             ...       ...
# 2022-04-25 00:00:00+00:00  1.081105  1.283088
# 2022-04-26 00:00:00+00:00  1.071421  1.273999
# 2022-04-27 00:00:00+00:00  1.064362  1.258400
# 2022-04-28 00:00:00+00:00  1.055509  1.254186
# 2022-04-29 00:00:00+00:00  1.050420  1.246385
#
# [3214 rows x 2 columns]

# %%
dados_2015 = dados_bancarios[dados_bancarios.index > "2015-01-01"]
dados_2015
# Out:
# Ticker                       EURJPY=X  EURUSD=X  GBPUSD=X       JPY=X
# Date
# 2015-01-02 00:00:00+00:00  144.929993  1.208941  1.557972  119.870003
# 2015-01-05 00:00:00+00:00  143.860001  1.194643  1.528491  120.433998
# 2015-01-06 00:00:00+00:00  142.557007  1.193902  1.525832  119.425003
# 2015-01-07 00:00:00+00:00  140.912003  1.187536  1.513798  118.672997
# 2015-01-08 00:00:00+00:00  141.156998  1.183600  1.510757  119.289001
# ...                               ...       ...       ...         ...
# 2022-04-25 00:00:00+00:00  139.028000  1.081105  1.283088  128.604996
# 2022-04-26 00:00:00+00:00  136.867004  1.071421  1.273999  127.744003
# 2022-04-27 00:00:00+00:00  135.449997  1.064362  1.258400  127.265999
# 2022-04-28 00:00:00+00:00  135.528000  1.055509  1.254186  128.393997
# 2022-04-29 00:00:00+00:00  137.391006  1.050420  1.246385  130.811005
#
# [1909 rows x 4 columns]

# %%
cotacao_maior_que_15 = dados_bancarios[dados_bancarios["EURUSD=X"] > 15]
cotacao_maior_que_15
# Out:
# Empty DataFrame
# Columns: [EURJPY=X, EURUSD=X, GBPUSD=X, JPY=X]
# Index: []

# %% [markdown]
# ### Voltando ao nosso projeto

# %%
eurusd = dados_bancarios["EURUSD=X"]
gbpusd = dados_bancarios["GBPUSD=X"]
usdjpy = dados_bancarios["JPY=X"]
eurjpy = dados_bancarios["EURJPY=X"]

# %%
def retorno(lista_cotacoes):

    retorno = lista_cotacoes[-1]/lista_cotacoes[0] - 1

    return retorno

# %%
retorno_eurusd = retorno(eurusd)
retorno_gbpusd = retorno(gbpusd)
retorno_usdjpy = retorno(usdjpy)
retorno_eurjpy = retorno(eurjpy)
# Out:
# C:\Users\gitar\AppData\Local\Temp\ipykernel_8776\1300698524.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   retorno = lista_cotacoes[-1]/lista_cotacoes[0] - 1

# %%
df_retornos = pd.DataFrame(

    data = {"retornos": [retorno_eurusd, retorno_gbpusd, retorno_usdjpy, retorno_eurjpy]},
    index = ["EUR/USD", "GBP/USD", "USD/JPY", "EUR/JPY"]
    
)

df_retornos
# Out:
#          retornos
# EUR/USD -0.270031
# GBP/USD -0.227428
# USD/JPY  0.407781
# EUR/JPY  0.027530

# %%
df_retornos["retornos"] = df_retornos["retornos"] * 100

df_retornos
# Out:
#           retornos
# EUR/USD -27.003149
# GBP/USD -22.742803
# USD/JPY  40.778096
# EUR/JPY   2.752973

# %%
df_retornos = df_retornos.sort_values(by = "retornos", ascending = False)

df_retornos
# Out:
#           retornos
# USD/JPY  40.778096
# EUR/JPY   2.752973
# GBP/USD -22.742803
# EUR/USD -27.003149

# %%
plt.style.use("cyberpunk")

# %%
fig, ax = plt.subplots()

ax.bar(df_retornos.index, df_retornos["retornos"])
ax.yaxis.set_major_formatter(mtick.PercentFormatter())

plt.xticks(fontsize = 9)

plt.show()

# %%
lucro_bancos
# Out:
#         data   EUR/USD   GBP/USD   USD/JPY   EUR/JPY
# 0 2009-12-31   8012282  10147522  10066608   1805899
# 1 2021-12-31  21945688  19710402  24988000  14987716

# %%
lucro_bancos = lucro_bancos.set_index("data")

lucro_bancos
# Out:
#              EUR/USD   GBP/USD   USD/JPY   EUR/JPY
# data
# 2009-12-31   8012282  10147522  10066608   1805899
# 2021-12-31  21945688  19710402  24988000  14987716

# %%
var_lucro_bancos = lucro_bancos.iloc[-1]/lucro_bancos.iloc[0] - 1

var_lucro_bancos
# Out:
# EUR/USD    1.739006
# GBP/USD    0.942386
# USD/JPY    1.482266
# EUR/JPY    7.299310
# dtype: float64

# %%
var_lucro_bancos = var_lucro_bancos * 100

# %%
var_lucro_bancos = var_lucro_bancos.sort_values(ascending = False)

# %%
fig, ax = plt.subplots()

ax.bar(var_lucro_bancos.index, var_lucro_bancos.values)
ax.yaxis.set_major_formatter(mtick.PercentFormatter())

plt.xticks(fontsize = 9)

plt.show()

# %%
fig, ax = plt.subplots()

ax.bar(df_retornos.index, df_retornos["retornos"])
ax.yaxis.set_major_formatter(mtick.PercentFormatter())

plt.xticks(fontsize = 9)

plt.show()

# %% [markdown]
# # Projeto 2

# %%
import pandas as pd
import matplotlib.pyplot as plt
import mplcyberpunk
import yfinance as yf
plt.style.use("cyberpunk")

# %%
itau = yf.download("ITUB4.SA", start = "2010-01-01", end = "2022-04-30")["Adj Close"]
bradesco = yf.download("BBDC4.SA", start = "2010-01-01", end = "2022-04-30")["Adj Close"]
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
def resample_periodo(dado, periodo):

    dado_periodo_novo = dado.resample(f"{periodo}").last()
    dado_periodo_novo = dado_periodo_novo.pct_change()
    dado_periodo_novo = dado_periodo_novo.dropna()

    return dado_periodo_novo

# %%
def long_short(long, short, periodo):

    var_long = resample_periodo(long, periodo)
    var_short = resample_periodo(short, periodo)

    outperform = (var_long - var_short) * 100
    print(outperform)
    plt.plot(outperform)

# %%
long_short(itau, bradesco, "Y")
# Out:
# C:\Users\gitar\AppData\Local\Temp\ipykernel_8776\1550704325.py:3: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   dado_periodo_novo = dado.resample(f"{periodo}").last()
# C:\Users\gitar\AppData\Local\Temp\ipykernel_8776\1550704325.py:3: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   dado_periodo_novo = dado.resample(f"{periodo}").last()
# Ticker                     BBDC4.SA  ITUB4.SA
# Date
# 2011-12-31 00:00:00+00:00       NaN       NaN
# 2012-12-31 00:00:00+00:00       NaN       NaN
# 2013-12-31 00:00:00+00:00       NaN       NaN
# 2014-12-31 00:00:00+00:00       NaN       NaN
# 2015-12-31 00:00:00+00:00       NaN       NaN
# 2016-12-31 00:00:00+00:00       NaN       NaN
# 2017-12-31 00:00:00+00:00       NaN       NaN
# 2018-12-31 00:00:00+00:00       NaN       NaN
# 2019-12-31 00:00:00+00:00       NaN       NaN
# 2020-12-31 00:00:00+00:00       NaN       NaN
# ...
